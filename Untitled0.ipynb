# %% [markdown]
# <a href="https://colab.research.google.com/github/kpbutterbearr36/36-cartoon-coding68/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("กรุณาระบุตัวเลข 1-9 ค่ะ : "))
if number == 1:
    print("เป็นเลขคี่ค่ะ")
elif number == 2:
    print("เป็นเลขคู่ค่ะ")
elif number == 3:
    print("เป็นเลขคี่ค่ะ")
elif number == 4:
    print("เป็นเลขคู่ค่ะ")
elif number == 5:
    print("เป็นเลขคี่ค่ะ")
elif number == 6:
    print("เป็นเลขคู่ค่ะ")
elif number == 7:
    print("เป็นเลขคี่ค่ะ")
elif number == 8:
    print("เป็นเลขคู่ค่ะ")
elif number == 9:
    print("เป็นเลขคี่ค่ะ")
# Out:
# กรุณาระบุตัวเลข 1-9 ค่ะ : 6
# เป็นเลขคู่ค่ะ
